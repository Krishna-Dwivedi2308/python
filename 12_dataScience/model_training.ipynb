# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split


df=pd.read_csv('comments.csv')

# %%
X_train,X_test,y_train,y_test=train_test_split(df['comment'],df['label'],test_size=0.2,random_state=42)

# %%
print(X_test,X_train,y_test,y_train,sep='\n')
# Out:
# 83            Thanks for the content
# 53            Keep up the great work
# 70    Can't believe people like this
# 45           Best tutorial I've seen
# 44                   Clickbait title
# 39                   You're a genius
# 22                   Clickbait title
# 80                    you're so dumb
# 10                    Cringe Content
# 0     Can't believe people like this
# 18               You're such a loser
# 30                    you're so dumb
# 73              So clear and helpful
# 33              So clear and helpful
# 90               You're such a loser
# 4                You're such a loser
# 76               You sound horrrible
# 77                    You're amazing
# 12                     Waste of time
# 31               Awesome explanation
# Name: comment, dtype: str
# 55    Best tutorial I've seen
# 88             you're so dumb
# 26             Cringe Content
# 42             you're so dumb
# 69     Keep up the great work
#                ...
# 60             you're so dumb
# 71       This helped me a lot
# 14        You're such a loser
# 92              Waste of time
# 51                  Great job
# Name: comment, Length: 80, dtype: str
# 83    supportive
# 53    supportive
# 70         toxic
# 45    supportive
# 44         toxic
# 39    supportive
# 22         toxic
# 80         toxic
# 10         toxic
# 0          toxic
# 18         toxic
# 30         toxic
# 73    supportive
# 33    supportive
# 90         toxic
# 4          toxic
# 76         toxic
# 77    supportive
# 12         toxic
# 31    supportive
# Name: label, dtype: str
# 55    supportive
# 88         toxic
# 26         toxic
# 42         toxic
# 69    supportive
#          ...
# 60         toxic
# 71    supportive
# 14         toxic
# 92         toxic
# 51    supportive
# Name: label, Length: 80, dtype: str

# %%
model=Pipeline([
        ('tfidf',TfidfVectorizer()),
        ('clf',LogisticRegression())
        ])

model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 1.0
